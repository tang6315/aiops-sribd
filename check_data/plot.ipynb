# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_feature(df, feature_list):
    for feature in feature_list:
        x_major_locator = plt.MultipleLocator(50)
        y_major_locator = plt.MultipleLocator(50)
        ax = plt.gca()
        plt.rcParams['figure.figsize'] = (20, 10)
        ax.xaxis.set_major_locator(x_major_locator)
        ax.yaxis.set_major_locator(y_major_locator)
        data[feature].plot(title=feature)
        plt.savefig('./features_plot/' + feature + '.jpg')
        plt.clf()

# %%
file_path = './train/' + str(684) + '.csv'
data = pd.read_csv(file_path)
data.drop(columns=['feature3_1', 'feature3_2', 'feature3_3', 
                   'feature3_4', 'feature3_5', 'feature3_6',
                   'feature3_7', 'feature3_8','feature14'], inplace=True)

# %%
data[feature_61].dropna(axis=0, how='all')[:60]
# Out:
#     feature61_0  feature61_1  feature61_2  feature61_3  feature61_4  \
# 0         -6.81       -10.88        -6.50        -8.38        -9.06
# 1        -11.38        -2.88        -6.31        -0.75        10.25
# 2          4.31        -6.38        -4.31         8.19        10.94
# 3        -17.75         3.00        -8.81        -8.44         0.00
# 5          2.88         8.38        12.13        -2.50         4.56
# 8          4.75         1.94        -3.63        -4.38        -3.25
# 9         -1.56        -2.50        -1.50        15.56         5.63
# 11        -4.81        -4.88         8.56        14.88        -0.31
# 12        -1.50         1.31         5.56        -6.06         6.25
# 13         6.25         6.38       -12.94       -18.38         4.25
# 14        -0.50         3.00       -17.19       -18.75         4.69
# 15         8.81        14.25        -0.25        -5.31         4.56
# 16        16.63        24.13         5.75         2.88         3.38
# ...

# %%
# plot_list = ['feature0', 'feature13', 'feature15']
feature_61= ['feature61_0', 'feature61_1', 'feature61_2',
             'feature61_3', 'feature61_4', 'feature61_5',
             'feature61_6', 'feature61_7']
plot_list = ['feature0', 'feature20_0', 'feature20_1', 'feature20_2', 'feature20_3']
plot_list_1 = ['feature0', 'feature20_4', 'feature20_5', 'feature20_6', 'feature20_7']
data[feature_61].plot(subplots=True, figsize=(20, 10))
# plt.savefig('./sfdjskf.jpg')
plt.show()

# %%
#     plt.show()
plot_feature(data, ['feature0', 'feature20_0', 'feature20_1', 'feature20_2', 'feature20_3'])
