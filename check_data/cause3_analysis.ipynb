# %%
import pandas as pd
import numpy as np

# %%
# 计算指标间的相关性
# 返回两个指标间的相关性
def corr_of_features(file):
    # file：文件路径
    # corr：
    df = pd.read_csv(file)
    columns = df.columns.to_list()
    zero_columns = df.loc[:, (df==0).any()].columns.tolist()
    for zero_column in zero_columns:
        columns.remove(zero_column)
    corr_result = {}
    corr = df['feature13'].corr(df['feature15'])
    return corr

# %%
cause3_nums = np.load('cause3_nums.npy')
cause3_nums = cause3_nums.tolist()

# %%
all_lists = []
for num in cause3_nums[:100]:
    file_name = str(num) + '.csv'
    file_path = './train/' + file_name
    one_top = corr_of_features(file_path)
    all_lists.append({str(num): one_top})
# Out:
# C:\Users\Tanghao\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\Tanghao\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
all_lists
# Out:
# [{'670': 0.9906805275614944},
#  {'673': 0.9948445829440627},
#  {'675': 0.9914177348491999},
#  {'684': 0.9952828917231166},
#  {'690': 0.9903740955374011},
#  {'694': 0.9851768804432478},
#  {'696': 0.998408465077861},
#  {'700': 0.9924873895385633},
#  {'703': 0.9934732173939969},
#  {'704': 0.9905122229328458},
#  {'712': 0.9712270751129797},
#  {'717': 0.997782043836223},
#  {'720': 0.9932542198367248},
#  {'721': 0.9951596277776514},
#  {'730': 0.9943372100135243},
#  {'735': 0.9953416576431808},
#  {'737': 0.999747130248765},
#  {'745': 0.9980393997650424},
#  {'768': 0.9244857098451528},
#  {'770': 0.8226572912771964},
#  {'771': 0.8906708518158573},
#  {'781': 0.875126205906868},
#  {'782': 0.9313349744529981},
#  {'787': 0.9343047375651752},
#  {'791': 0.9693950489010508},
#  {'798': 0.9179895872586462},
#  {'814': 0.8662989191765419},
#  {'816': 0.6250906352002826},
#  {'827': 0.9319957943469591},
#  {'834': 0.9991783558059317},
#  {'836': 0.8268192670509382},
#  {'846': 0.9598333887512646},
#  {'852': 0.8702259276569271},
#  {'868': 0.9703580176598828},
#  {'870': 0.430298911035293},
#  {'871': 0.8751134101336538},
#  {'877': 0.9373425090056091},
#  {'883': 0.9849713239899318},
#  {'890': 0.9816170368940286},
#  {'896': 0.9979894995910696},
#  {'901': 0.9758527799252508},
#  {'913': 0.9463951885229092},
#  {'959': 0.9849400462437585},
#  {'965': 0.984739412035513},
#  {'966': 0.9927751736808658},
#  {'967': 0.97584216284573},
#  {'968': nan},
#  {'970': 0.8725877480516172},
#  {'972': 0.9966678177712941},
#  {'979': 0.9807468273086304},
#  {'997': 0.9720989030908077},
#  {'1004': 0.9984259909602822},
#  {'1009': 0.9765905925549314},
#  {'1033': 0.9885276812746677},
#  {'1045': 0.9758978520159012},
#  {'1050': 0.9852447713481844},
#  {'1077': 0.9983044923080693},
#  {'1079': 0.9755187887850518},
#  {'1084': 0.9970000623694105},
#  {'1085': 0.9840134515383033},
#  {'1113': 0.964133531337077},
#  {'1119': 0.9972278004826279},
#  {'1124': 0.994582431158121},
#  {'1130': 0.9874934042078244},
#  {'1145': 0.28411401027291794},
#  {'1159': 0.9753294351005773},
#  {'1162': 0.9876885343659915},
#  {'1168': 0.9741209009956512},
#  {'1169': 0.9881041753576416},
#  {'1170': 0.9991313977292213},
#  {'1202': 0.9868082457161084},
#  {'1208': 0.9897684357917098},
#  {'1213': 0.9952669250232579},
#  {'1214': 0.9992521422202749},
#  {'1221': 0.9895495020605861},
#  {'1226': 0.9552671961925036},
#  {'1234': 0.9876170643741193},
#  {'1239': 0.9941032175401381},
#  {'1240': 0.9988324635131173},
#  {'1246': 0.990824664265132},
#  {'1278': 0.9984846911973816},
#  {'1283': 0.33572812863371887},
#  {'1301': 0.9953895297179971},
#  {'1342': 0.9891120555809017},
#  {'1367': 0.9899426068668365},
#  {'1372': 0.9850098989879725},
#  {'1378': 0.9927292470235786},
#  {'1382': 0.9764322996348129},
#  {'1388': 0.9976522294761677},
#  {'1401': 0.9938430995087606},
#  {'1403': 0.9985279026665543},
#  {'1406': 0.9910787511891824},
#  {'1415': 0.9783209431572547},
#  {'1418': 0.9922822090400557},
#  {'1424': 0.7377405797303037},
#  {'1426': 0.9950904584279481},
#  {'1428': 0.9989153984897831},
#  {'1429': 0.9750386625968603},
#  {'1430': 0.9810841255787357},
#  {'1436': 0.9876737477847682}]
