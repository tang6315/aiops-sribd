# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-65be4b72299f> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotliba.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotliba'

# %%
train_label = pd.read_csv('./train_label.csv')

# %%
train_label
# Out:
#       sample_index root-cause(s)
# 0              670    rootcause3
# 1              673    rootcause3
# 2              675    rootcause3
# 3              684    rootcause3
# 4              690    rootcause3
# ...            ...           ...
# 1402          2979    rootcause3
# 1403          2980    rootcause3
# 1404          2981    rootcause3
# 1405          2982    rootcause3
# 1406          2983    rootcause3
#
# [1407 rows x 2 columns]

# %%
train_label[['root-cause(s)']].apply(pd.value_counts)
# Out:
#                        root-cause(s)
# rootcause3                      1213
# rootcause1                       112
# rootcause2&rootcause3             71
# rootcause2                        11

# %%
cause1_nums = train_label[train_label['root-cause(s)']=='rootcause1']['sample_index'].to_list()
cause1_nums
# cause1_nums = np.array(cause1_nums)
# np.save('cause3_nums.npy', cause1_nums)
# Out:
# [914,
#  915,
#  916,
#  917,
#  918,
#  919,
#  920,
#  921,
#  922,
#  924,
#  925,
#  926,
#  927,
#  928,
#  929,
#  991,
#  993,
#  1007,
#  1021,
#  1034,
#  1037,
#  1142,
#  1171,
#  1250,
#  1251,
#  1252,
#  1255,
#  1257,
#  1258,
#  1380,
#  1414,
#  1490,
#  1540,
#  1547,
#  1573,
#  1781,
#  1786,
#  1823,
#  1824,
#  1825,
#  1843,
#  1846,
#  1852,
#  1878,
#  1879,
#  1883,
#  1884,
#  1887,
#  1888,
#  1904,
#  1913,
#  1914,
#  1918,
#  1924,
#  1931,
#  1937,
#  1938,
#  1958,
#  1973,
#  1981,
#  1988,
#  1989,
#  1992,
#  1993,
#  1994,
#  1995,
#  2006,
#  2015,
#  2040,
#  2041,
#  2043,
#  2067,
#  2074,
#  2089,
#  2090,
#  2093,
#  2105,
#  2125,
#  2130,
#  2152,
#  2171,
#  2205,
#  2231,
#  2232,
#  2274,
#  2276,
#  2285,
#  2303,
#  2361,
#  2367,
#  2425,
#  2511,
#  2517,
#  2525,
#  2526,
#  2527,
#  2549,
#  2558,
#  2559,
#  2565,
#  2586,
#  2587,
#  2603,
#  2605,
#  2606,
#  2613,
#  2614,
#  2620,
#  2662,
#  2725,
#  2917,
#  2946]

# %%
file_path = './train/' + str(915) + '.csv'
data = pd.read_csv(file_path)
data
# data.drop(columns='Date & Time', inplace=True)
# Out:
#                Date & Time  feature0  feature1  feature2  feature3_1  \
# 0    \t2020-08-13 15:58:43      0.08      7.00      1.90         4.0
# 1    \t2020-08-13 15:58:44      2.42     15.16      3.00         0.0
# 2    \t2020-08-13 15:58:45     40.91     18.21      3.00         0.0
# 3    \t2020-08-13 15:58:46    268.92     21.59      3.51         0.0
# 4    \t2020-08-13 15:58:47    297.54     22.30      3.90         0.0
# ..                     ...       ...       ...       ...         ...
# 459  \t2020-08-13 16:06:23    286.21     16.69      3.00         0.0
# 460  \t2020-08-13 16:06:24    285.19     17.68      3.00         0.0
# 461  \t2020-08-13 16:06:25    276.60     17.88      3.00         0.0
# 462  \t2020-08-13 16:06:26    276.74     16.52      3.00         0.0
# 463  \t2020-08-13 16:06:26    284.69     17.30      3.00         0.0
#
#      feature3_2  feature3_3  feature3_4  feature3_5  feature3_6  ...  \
# ...

# %%
data.columns
# Out:
# Index(['Date & Time', 'feature0', 'feature1', 'feature2', 'feature3_1',
#        'feature3_2', 'feature3_3', 'feature3_4', 'feature3_5', 'feature3_6',
#        'feature3_7', 'feature3_8', 'feature11', 'feature12', 'feature13',
#        'feature14', 'feature15', 'feature16', 'feature17', 'feature18',
#        'feature19', 'feature20_0', 'feature20_1', 'feature20_2', 'feature20_3',
#        'feature20_4', 'feature20_5', 'feature20_6', 'feature20_7',
#        'feature28_0', 'feature28_1', 'feature28_2', 'feature28_3',
#        'feature28_4', 'feature28_5', 'feature28_6', 'feature28_7',
#        'feature36_0', 'feature36_1', 'feature36_2', 'feature36_3',
#        'feature36_4', 'feature36_5', 'feature36_6', 'feature36_7',
#        'feature44_0', 'feature44_1', 'feature44_2', 'feature44_3',
#        'feature44_4', 'feature44_5', 'feature44_6', 'feature44_7',
#        'feature52_0', 'feature52_1', 'feature52_2', 'feature52_3',
# ...

# %%
data.drop(columns=['feature3_1', 'feature3_2', 'feature3_3', 
                   'feature3_4', 'feature3_5', 'feature3_6',
                   'feature3_7', 'feature3_8','feature14'])
# Out:
#                Date & Time  feature0  feature1  feature2  feature11  \
# 0    \t2020-08-13 15:58:43      0.08      7.00      1.90        0.0
# 1    \t2020-08-13 15:58:44      2.42     15.16      3.00        0.0
# 2    \t2020-08-13 15:58:45     40.91     18.21      3.00        0.0
# 3    \t2020-08-13 15:58:46    268.92     21.59      3.51        0.0
# 4    \t2020-08-13 15:58:47    297.54     22.30      3.90        0.0
# ..                     ...       ...       ...       ...        ...
# 459  \t2020-08-13 16:06:23    286.21     16.69      3.00        0.0
# 460  \t2020-08-13 16:06:24    285.19     17.68      3.00        0.0
# 461  \t2020-08-13 16:06:25    276.60     17.88      3.00        0.0
# 462  \t2020-08-13 16:06:26    276.74     16.52      3.00        0.0
# 463  \t2020-08-13 16:06:26    284.69     17.30      3.00        0.0
#
#      feature12  feature13  feature15  feature16  feature17  ...  feature77_6  \
# ...
